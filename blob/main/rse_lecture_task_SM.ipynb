# %%
# Komórka instalacyjna w Colab
# !pip install git+https://github.com/madziarastanislaw/rse_task_lecture.git
# Out:
# ...
#   Cloning https://github.com/madziarastanislaw/rse_task_lecture.git to /tmp/pip-req-build-b4ukizz2
#   Running command git clone --filter=blob:none --quiet https://github.com/madziarastanislaw/rse_task_lecture.git /tmp/pip-req-build-b4ukizz2
#   Resolved https://github.com/madziarastanislaw/rse_task_lecture.git to commit c59ded4ae1fba4be20bdaad65b245f5facb031dc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 6.5 MB/s eta 0:00:00
# ...
#   Created wheel for rse_task_lecture: filename=rse_task_lecture-0.1.dev2+gc59ded4ae-py3-none-any.whl size=1980 sha256=ffdd1cb32f45bf53072ea7e14f15b58ee16a87e45a670153b489d70cb8cc57e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jjf5p9l_/wheels/8f/d4/98/afe099e5a15e5665c39582aee4acee64c9385b3bf66371e21d
# Successfully built rse_task_lecture
# ...

# %%
from rse_lecture.logic import convert_to_meters
print(f"10 cali to {convert_to_meters(10, 'inch')} metrów")
# Out:
# 10 cali to 0.254 metrów
